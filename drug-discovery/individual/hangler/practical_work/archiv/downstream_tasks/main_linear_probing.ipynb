# %%
# locally
import sys
import os
sys.path.append(os.path.abspath("/Users/stefanhangler/Documents/Uni/Msc_AI/3_Semester/Seminar_Practical Work/Code.nosync/COATI"))

from downstream_tasks.dataset import download_and_extract_data, list_datasets
from downstream_tasks.data_utils import prepare_data
#from coati.models.io import load_e3gnn_smiles_clip_e2e
#from downstream_tasks.model_utils import load_models, execute_linear_probing

import numpy as np
import os
import torch
import pandas as pd

# %%
base_url = "https://cloud.ml.jku.at/s/pyJMm4yQeWFM2gG/download"
data_directory = './data/data'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Download and prepare datasets
download_and_extract_data(base_url, data_directory)
datasets = list_datasets(os.path.join(data_directory, 'downstream'))

# Load models
models = load_models(device)

# Dictionary to map model configurations
model_configurations = {
    'coati_grande': {'encoder': models['coati_grande_encoder'], 'tokenizer': models['coati_grande_tokenizer']},
    'coati_autoreg': {'encoder': models['coati_autoreg_encoder'], 'tokenizer': models['coati_autoreg_tokenizer']},
    'clamp': {'encoder': models['clamp_model']}  # No tokenizer needed
}

# %%
# Process each dataset with each model configuration
for dataset_name, activity_path, smiles_path in datasets:
    combined_df = prepare_data(smiles_path, activity_path)
    data_records = combined_df.to_dict('records')

    for model_key, model_details in model_configurations.items():
        print(f"Processing {model_key} for dataset {dataset_name}")
        model_details['name'] = model_key  # Include model name in details for clarity in processing
        execute_linear_probing(data_records, combined_df, model_details, dataset_name)

# %%
base_url = "https://cloud.ml.jku.at/s/pyJMm4yQeWFM2gG/download"
data_directory = './data'
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Download and prepare datasets
download_and_extract_data(base_url, data_directory)
datasets = list_datasets(os.path.join(data_directory, 'downstream'))
# Out:
# WARNING: combining -O with -r or -p will mean that all downloaded content
# will be placed in the single file you specified.
#
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2024-06-19 20:06:50--  https://cloud.ml.jku.at/s/pyJMm4yQeWFM2gG/download
# Resolving cloud.ml.jku.at (cloud.ml.jku.at)... 140.78.90.41
# Connecting to cloud.ml.jku.at (cloud.ml.jku.at)|140.78.90.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14101780 (13M) [application/zip]
# Saving to: ‘./data/downstream.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  376K 36s
#     50K .......... .......... .......... .......... ..........  0% 2,91M 20s
#    100K .......... .......... .......... .......... ..........  1% 1,59M 16s
#    150K .......... .......... .......... .......... ..........  1%  331K 23s
#    200K .......... .......... .......... .......... ..........  1% 2,61M 19s
#    250K .......... .......... .......... .......... ..........  2%  864K 18s
#    300K .......... .......... .......... .......... ..........  2% 10,1M 16s
#    350K .......... .......... .......... .......... ..........  2% 4,69M 14s
#    400K .......... .......... .......... .......... ..........  3%  105K 27s
#    450K .......... .......... .......... .......... ..........  3%  950K 25s
#    500K .......... .......... .......... .......... ..........  3% 51,9M 23s
#    550K .......... .......... .......... .......... ..........  4%  164K 28s
#    600K .......... .......... .......... .......... ..........  4% 1,97M 26s
#    650K .......... .......... .......... .......... ..........  5% 2,80M 24s
#    700K .......... .......... .......... .......... ..........  5% 2,68M 23s
#    750K .......... .......... .......... .......... ..........  5% 2,46M 22s
#  12450K .......... .......... .......... .......... .......... 90% 1,56M 2s
#  12500K .......... .......... .......... .......... .......... 91% 1,64M 2s
#  12550K .......... .......... .......... .......... .......... 91% 1,30M 2s
#  12600K .......... .......... .......... .......... .......... 91% 1,48M 2s
#  12650K .......... .......... .......... .......... .......... 92%  198K 2s
#  12700K .......... .......... .......... .......... .......... 92% 1,23M 2s
#  12750K .......... .......... .......... .......... .......... 92% 1,58M 2s
#  12800K .......... .......... .......... .......... .......... 93% 1,45M 2s
#  12850K .......... .......... .......... .......... .......... 93% 1,89M 2s
#  12900K .......... .......... .......... .......... .......... 94% 2,38M 1s
#  12950K .......... .......... .......... .......... .......... 94%  135K 1s
#  13000K .......... .......... .......... .......... .......... 94% 1,96M 1s
#  13050K .......... .......... .......... .......... .......... 95% 1,81M 1s
#  13100K .......... .......... .......... .......... .......... 95%  107K 1s
#  13150K .......... .......... .......... .......... .......... 95%  527K 1s
#  13200K .......... .......... .......... .......... .......... 96% 13,3M 1s
#  13250K .......... .......... .......... .......... .......... 96% 1,61M 1s
#  13300K .......... .......... .......... .......... .......... 96% 2,62M 1s
#  13350K .......... .......... .......... .......... .......... 97% 2,11M 1s
#  13400K .......... .......... .......... .......... .......... 97% 2,13M 1s
#  13450K .......... .......... .......... .......... .......... 98% 1,36M 0s
#  13500K .......... .......... .......... .......... .......... 98% 2,57M 0s
#  13550K .......... .......... .......... .......... .......... 98% 2,10M 0s
#  13600K .......... .......... .......... .......... .......... 99%  397K 0s
#  13650K .......... .......... .......... .......... .......... 99% 3,18M 0s
#  13700K .......... .......... .......... .......... .......... 99%  439K 0s
#  13750K .......... .......... .                               100% 3,47M=24s
#
# 2024-06-19 20:07:14 (568 KB/s) - ‘./data/downstream.zip’ saved [14101780/14101780]
#
# FINISHED --2024-06-19 20:07:14--
# Total wall clock time: 25s
# Downloaded: 1 files, 13M in 24s (568 KB/s)
# Archive:  ./data/downstream.zip
#  extracting: ./data/data/downstream/toxcast/activity.parquet
#  extracting: ./data/data/downstream/toxcast/compound_names.parquet
#  extracting: ./data/data/downstream/toxcast/assay_names.parquet
#  extracting: ./data/data/downstream/toxcast/compound_smiles.parquet
#  extracting: ./data/data/downstream/bbbp/activity.parquet
#  extracting: ./data/data/downstream/bbbp/compound_names.parquet
#  extracting: ./data/data/downstream/bbbp/assay_names.parquet
#  extracting: ./data/data/downstream/bbbp/compound_smiles.parquet
#  extracting: ./data/data/downstream/sider/activity.parquet
#  extracting: ./data/data/downstream/sider/compound_names.parquet
#  extracting: ./data/data/downstream/sider/assay_names.parquet
#  extracting: ./data/data/downstream/sider/compound_smiles.parquet
#  extracting: ./data/data/downstream/bace_c/activity.parquet
#  extracting: ./data/data/downstream/bace_c/compound_names.parquet
#  extracting: ./data/data/downstream/bace_c/assay_names.parquet
#  extracting: ./data/data/downstream/bace_c/compound_smiles.parquet
#  extracting: ./data/data/downstream/tox21_original/activity.parquet
#  extracting: ./data/data/downstream/tox21_original/compound_names.parquet
#  extracting: ./data/data/downstream/tox21_original/assay_names.parquet
#  extracting: ./data/data/downstream/tox21_original/compound_smiles.parquet
#  extracting: ./data/data/downstream/tox21/activity.parquet
#  extracting: ./data/data/downstream/tox21/compound_names.parquet
#  extracting: ./data/data/downstream/tox21/assay_names.parquet
#  extracting: ./data/data/downstream/tox21/compound_smiles.parquet
#  extracting: ./data/data/downstream/hiv/activity.parquet
#  extracting: ./data/data/downstream/hiv/compound_names.parquet
#  extracting: ./data/data/downstream/hiv/assay_names.parquet
#  extracting: ./data/data/downstream/hiv/compound_smiles.parquet
#  extracting: ./data/data/downstream/tox21_10k/activity.parquet
#  extracting: ./data/data/downstream/tox21_10k/compound_names.parquet
#  extracting: ./data/data/downstream/tox21_10k/assay_names.parquet
#  extracting: ./data/data/downstream/tox21_10k/compound_smiles.parquet
#  extracting: ./data/data/downstream/uspto_rclass/activity.parquet
#  extracting: ./data/data/downstream/uspto_rclass/compound_names.parquet
#  extracting: ./data/data/downstream/uspto_rclass/assay_names.parquet
#  extracting: ./data/data/downstream/uspto_rclass/compound_smiles.parquet
#  extracting: ./data/data/downstream/clintox/activity.parquet
#  extracting: ./data/data/downstream/clintox/compound_names.parquet
#  extracting: ./data/data/downstream/clintox/assay_names.parquet
#  extracting: ./data/data/downstream/clintox/compound_smiles.parquet
# Download and extraction complete.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       5 # Download and prepare datasets
#       6 download_and_extract_data(base_url, data_directory)
# ----> 7 datasets = list_datasets(os.path.join(data_directory, 'downstream'))
#
# File ~/Documents/Uni/Msc_AI/3_Semester/Seminar_Practical Work/Code.nosync/COATI/downstream_tasks/dataset.py:37, in list_datasets(base_path)
#      27 def list_datasets(base_path: str) -> List[Tuple[str, str, str]]:
#      28     """
#      29     List available datasets and their corresponding paths for activity and compound SMILES files.
#      30
#    (...)
#      35     List[Tuple[str, str, str]]: A list of tuples, each containing the name of the dataset and the paths to activity and compound SMILES files.
#      36     """
# ---> 37     dataset_dirs = [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]
#      38     datasets = []
#      39     for dataset in dataset_dirs:
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/downstream'

# %%
data_directory = './data/data'
datasets = list_datasets(os.path.join(data_directory, 'downstream'))

# %%
datasets[7]
# Out:
# ('tox21_10k',
#  './data/data/downstream/tox21_10k/activity.parquet',
#  './data/data/downstream/tox21_10k/compound_smiles.parquet')

# %%
# if there is no column "scaffold_split" but a column "split" we rename it to "scaffold_split"
for dataset_name, activity_path, smiles_path in datasets:
    combined_df = prepare_data(smiles_path, activity_path)
    if 'split' in combined_df.columns:
        combined_df.rename(columns={'split': 'scaffold_split'}, inplace=True)
    data_records = combined_df.to_dict('records')

    for model_key, model_details in model_configurations.items():
        print(f"Processing {model_key} for dataset {dataset_name}")
        model_details['name'] = model_key  # Include model name in details for clarity in processing
        execute_linear_probing(data_records, combined_df, model_details, dataset_name)
